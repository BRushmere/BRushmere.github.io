# %%
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader.data as web
import matplotlib
# %matplotlib inline
import numpy as np
from datetime import datetime
import scipy.stats as sts
import pprint
start = datetime(2015, 2, 9)
end = datetime(2017, 5, 24)

# %%
Symbols = ['AAPL','AMZN','MSFT','JPM']

data = pd.DataFrame()

for sym in Symbols:
    data[sym] = web.DataReader(sym,'iex', start, end)['close']
  

print(data.head())
# Out:
# 5y
# 5y
# 5y
# 5y
#                 AAPL     AMZN     MSFT      JPM
# date
# 2015-02-09  112.4852  370.560  38.7580  52.9660
# 2015-02-10  114.6462  372.995  38.9776  53.5522
# 2015-02-11  117.3333  375.140  38.7763  53.4698
# 2015-02-12  118.8179  377.170  39.4260  54.5690
# 2015-02-13  119.4004  381.830  40.1396  54.6606

# %%
returns = data/data.iloc[0]
log_returns= np.log(data/data.shift(1))

print(returns.plot())
print(log_returns.hist(bins=50))

print(sts.describe(data))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00A71A30>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00C3E950>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x00C57AB0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00C71C10>]]
# DescribeResult(nobs=578, minmax=(array([ 86.9805, 366.37  ,  37.1264,  49.946 ]), array([153.1733, 980.35  ,  67.8198,  90.5873])), mean=array([111.81490588, 648.6041955 ,  50.95589723,  65.2771218 ]), variance=array([  206.78130301, 26838.60086075,    64.23329432,   112.33762218]), skewness=array([ 0.63505597, -0.100066  ,  0.21904611,  1.04955833]), kurtosis=array([ 0.1145041 , -1.08282665, -0.95552458, -0.34858447]))
