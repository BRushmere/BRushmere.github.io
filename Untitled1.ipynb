# %%
import matplotlib.pyplot as plt
#Plot 1 to 5 and x^2
xVals = list(range(6))
yVals = [x**2 for x in xVals]
# %matplotlib inline
plt.plot(xVals,yVals)
plt.xlabel("X")
plt.ylabel("X^2")
plt.title("X^2 Graph")
plt.show()
